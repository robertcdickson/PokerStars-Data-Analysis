# %% [markdown]
# An example notebook on how to use the PokerStarsCollection and PokerStarsGame classes
# ---

# %%
from pokerstars import PokerStarsCollection
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# A PokerStarsCollection is a collection of PokerStarsGame's that occur in a single session. The encoding needs to be changed for windows/linux otherwise various errors will occur.

# %%
poker_session = PokerStarsCollection(file="./multigame_example_anonymized.txt",
                                     encoding=None,
                                     working_dir="./",
                                     hero="Bobson_Dugnutt")

# %% [markdown]
# Games can be accessed from the `games_data` attribute of `PokerStarsCollection`. To get a complete dataframe, use the `get_full_data()` method.

# %%
single_game = poker_session.games_data[4].get_full_data()
print(single_game)
# Out:
#         Player Name       Stakes Max Players Game Type        Date      Time  \
# 0   Sleve_McDichael  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 1  Darryl_Archideld  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 2    Willie_Dustice  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 3    Bobson_Dugnutt  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 4     Scott_Dourque  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 5         Mike_Truk  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 6      Tim_Sandaele  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 7    Karl_Dandleton  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
# 8     Todd_Bonzalez  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:37
#
#       Game Code   Table Name  Chips ($)  Chips (BB)  ... Pre-Flop Raise  \
# 0  223646511216  Ornamenta V       2.10       105.0  ...          False
# 1  223646511216  Ornamenta V       2.00       100.0  ...          False
# 2  223646511216  Ornamenta V       5.23       261.5  ...          False
# 3  223646511216  Ornamenta V       2.00       100.0  ...          False
# 4  223646511216  Ornamenta V       0.22        11.0  ...          False
# 5  223646511216  Ornamenta V       1.73        86.5  ...          False
# 6  223646511216  Ornamenta V       1.96        98.0  ...          False
# 7  223646511216  Ornamenta V       2.08       104.0  ...           True
# 8  223646511216  Ornamenta V       1.54        77.0  ...          False
#
#   Pre-Flop Raise Size  Pre-Flop Raise to Called Pre-Flop Raise  \
# 0                 NaN                NaN                 False
# 1                 NaN                NaN                 False
# 2                 NaN                NaN                 False
# 3                 NaN                NaN                 False
# 4                 NaN                NaN                 False
# 5                 NaN                NaN                 False
# 6                 NaN                NaN                 False
# 7                0.03               0.05                 False
# 8                 NaN                NaN                  True
#
#   Called Pre-Flop Raise size  Fold to Pre-Flop Raise Check Flop Turn Raise  \
# 0                        NaN                    True        NaN        NaN
# 1                        NaN                    True        NaN        NaN
# 2                        NaN                    True        NaN        NaN
# 3                        NaN                    True        NaN        NaN
# 4                        NaN                    True        NaN        NaN
# 5                        NaN                    True        NaN        NaN
# 6                        NaN                    True        NaN        NaN
# 7                        NaN                     NaN       True       True
# 8                       0.05                     NaN       True      False
#
#   Turn Raise Size Fold to Turn Raise
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
# 5             NaN                NaN
# 6             NaN                NaN
# 7            0.07                NaN
# 8             NaN               True
#
# [9 rows x 22 columns]

# %% [markdown]
# Currently, a full dataframe is saved in the `full_data` attribute of `PokerStarsCollection`.

# %%
full_data = poker_session.full_data
print(full_data)
# Out:
#           Player Name       Stakes Max Players Game Type        Date  \
# 0     Sleve_McDichael  $0.01/$0.02       9-max    Normal  2021/02/10
# 1    Darryl_Archideld  $0.01/$0.02       9-max    Normal  2021/02/10
# 2      Willie_Dustice  $0.01/$0.02       9-max    Normal  2021/02/10
# 3      Bobson_Dugnutt  $0.01/$0.02       9-max    Normal  2021/02/10
# 4       Scott_Dourque  $0.01/$0.02       9-max    Normal  2021/02/10
# ..                ...          ...         ...       ...         ...
# 121     Scott_Dourque  $0.01/$0.02       9-max    Normal  2021/02/10
# 122         Mike_Truk  $0.01/$0.02       9-max    Normal  2021/02/10
# 123      Tim_Sandaele  $0.01/$0.02       9-max    Normal  2021/02/10
# 124    Karl_Dandleton  $0.01/$0.02       9-max    Normal  2021/02/10
# 125     Todd_Bonzalez  $0.01/$0.02       9-max    Normal  2021/02/10
#
#          Time     Game Code   Table Name  Chips ($)  Chips (BB)  ...  \
# 0    15:46:32  223646450352  Ornamenta V       2.03       101.5  ...
# 1    15:46:32  223646450352  Ornamenta V       1.97        98.5  ...
# 2    15:46:32  223646450352  Ornamenta V       5.19       259.5  ...
# 3    15:46:32  223646450352  Ornamenta V       2.00       100.0  ...
# 4    15:46:32  223646450352  Ornamenta V       0.25        12.5  ...
# ..        ...           ...          ...        ...         ...  ...
# 121  15:57:31  223646760069  Ornamenta V       0.19         9.5  ...
# 122  15:57:31  223646760069  Ornamenta V       2.51       125.5  ...
# 123  15:57:31  223646760069  Ornamenta V       1.91        95.5  ...
# 124  15:57:31  223646760069  Ornamenta V       2.00       100.0  ...
# 125  15:57:31  223646760069  Ornamenta V       1.58        79.0  ...
#
#     Check Turn Turn Raise Turn Raise Size Called Turn Raise  \
# 0          NaN        NaN             NaN               NaN
# 1          NaN        NaN             NaN               NaN
# 2          NaN        NaN             NaN               NaN
# 3          NaN        NaN             NaN               NaN
# 4          NaN        NaN             NaN               NaN
# ..         ...        ...             ...               ...
# 121        NaN        NaN             NaN               NaN
# 122        NaN      False             NaN              True
# 123        NaN        NaN             NaN               NaN
# 124        NaN        NaN             NaN               NaN
# 125        NaN        NaN             NaN               NaN
#
#     Called Turn Raise size Fold to Turn Raise River Raise River Raise Size  \
# 0                      NaN                NaN         NaN              NaN
# 1                      NaN                NaN         NaN              NaN
# 2                      NaN                NaN         NaN              NaN
# 3                      NaN                NaN         NaN              NaN
# 4                      NaN                NaN         NaN              NaN
# ..                     ...                ...         ...              ...
# 121                    NaN                NaN         NaN              NaN
# 122                   0.21                NaN       False              NaN
# 123                    NaN                NaN         NaN              NaN
# 124                    NaN                NaN         NaN              NaN
# 125                    NaN                NaN         NaN              NaN
#
#     Called River Raise Called River Raise size
# 0                  NaN                     NaN
# 1                  NaN                     NaN
# 2                  NaN                     NaN
# 3                  NaN                     NaN
# 4                  NaN                     NaN
# ..                 ...                     ...
# 121                NaN                     NaN
# 122               True                    0.80
# 123                NaN                     NaN
# 124                NaN                     NaN
# 125                NaN                     NaN
#
# [126 rows x 43 columns]

# %% [markdown]
# From this full dataframe, all pandas functionality can be used. For example filtering by hands in which anyone 3-bet pre-flop:

# %%
three_bets = full_data[(full_data["Pre-Flop 3-Bet"] == True)]
three_bets
# Out:
#          Player Name       Stakes Max Players Game Type        Date      Time  \
# 48    Bobson_Dugnutt  $0.01/$0.02       9-max    Normal  2021/02/10  15:50:43
# 62     Todd_Bonzalez  $0.01/$0.02       9-max    Normal  2021/02/10  15:51:33
# 64  Darryl_Archideld  $0.01/$0.02       9-max    Normal  2021/02/10  15:52:34
#
#        Game Code   Table Name  Chips ($)  Chips (BB)  ... Check Turn  \
# 48  223646572650  Ornamenta V       2.14       107.0  ...        NaN
# 62  223646597506  Ornamenta V       1.47        73.5  ...        NaN
# 64  223646627150  Ornamenta V       2.00       100.0  ...        NaN
#
#    Turn Raise Turn Raise Size Called Turn Raise Called Turn Raise size  \
# 48        NaN             NaN               NaN                    NaN
# 62        NaN             NaN               NaN                    NaN
# 64        NaN             NaN               NaN                    NaN
#
#    Fold to Turn Raise River Raise River Raise Size Called River Raise  \
# 48                NaN         NaN              NaN                NaN
# 62                NaN         NaN              NaN                NaN
# 64                NaN         NaN              NaN                NaN
#
#    Called River Raise size
# 48                     NaN
# 62                     NaN
# 64                     NaN
#
# [3 rows x 43 columns]

# %% [markdown]
# Filters can be combined as follows:

# %%
bobson_raise = full_data[(full_data["Player Name"] == "Bobson_Dugnutt") & (full_data["Pre-Flop Raise"] == True)]
bobson_raise
# Out:
#         Player Name       Stakes Max Players Game Type        Date      Time  \
# 21   Bobson_Dugnutt  $0.01/$0.02       9-max    Normal  2021/02/10  15:48:06
# 39   Bobson_Dugnutt  $0.01/$0.02       9-max    Normal  2021/02/10  15:49:31
# 111  Bobson_Dugnutt  $0.01/$0.02       9-max    Normal  2021/02/10  15:56:47
#
#         Game Code   Table Name  Chips ($)  Chips (BB)  ... Check Turn  \
# 21   223646496026  Ornamenta V       1.95        97.5  ...        NaN
# 39   223646537550  Ornamenta V       2.00       100.0  ...        NaN
# 111  223646742573  Ornamenta V       1.27        63.5  ...        NaN
#
#     Turn Raise Turn Raise Size Called Turn Raise Called Turn Raise size  \
# 21         NaN             NaN               NaN                    NaN
# 39        True            0.14               NaN                    NaN
# 111      False             NaN               NaN                    NaN
#
#     Fold to Turn Raise River Raise River Raise Size Called River Raise  \
# 21                 NaN         NaN              NaN                NaN
# 39                 NaN         NaN              NaN                NaN
# 111               True         NaN              NaN                NaN
#
#     Called River Raise size
# 21                      NaN
# 39                      NaN
# 111                     NaN
#
# [3 rows x 43 columns]

# %% [markdown]
# A very useful application of this filtering of data is to plot different hand matrices to get a clear illustration of how often different hands are played in different situtations.

# %%
def plot_hand_matrix(hand_counts):
    # uses df counts to plot a heatmap in a hand matrix
    def translate_hand(hand=None):
        if hand[-1] == "s":
            new_hand = hand[0] + hand[1]
        elif hand[-1] == "o":
            new_hand = hand[1] + hand[0]
        else:
            return hand
        return new_hand

    list_of_rankings = ["A", "K", "Q", "J", "T", "9", "8", "7", "6", "5", "4", "3", "2"]
    data_counter = {a: {b: 0  for b in list_of_rankings} for a in list_of_rankings}
    for x, y in zip(list(hand_counts.index), hand_counts):
        x = x.replace(" ", "")
        if x[0] == x[2]:
            counter_key = x[0] + x[2]
        elif x[1] == x[3]:
            counter_key = x[0] + x[2]
        else:
            counter_key = x[2] + x[0]
        data_counter[counter_key[0]][counter_key[1]] += y

    heatmap_data = pd.DataFrame.from_dict(data_counter)

    plt.figure(figsize=(12, 12))
    all_ranking_combos = []
    for x in list_of_rankings:
        row = []
        for y in list_of_rankings:
            if list_of_rankings.index(x) < list_of_rankings.index(y):
                row.append(x + y + "s")
            elif list_of_rankings.index(x) > list_of_rankings.index(y):
                row.append(y + x + "o")
            else:
                row.append(x + y)
        all_ranking_combos.append(row)

    rankings = pd.DataFrame(all_ranking_combos)
    sns.heatmap(heatmap_data, annot=all_ranking_combos, fmt = '', xticklabels=False,
                yticklabels=False, cmap=plt.cm.get_cmap("magma"), linewidths=2.5, linecolor = (0.2, 0.2, 0.2),
                annot_kws={"fontsize": 20}, cbar=False)

# %%
plot_hand_matrix(full_data["Player Cards"].value_counts())
